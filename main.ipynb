# %%
import pandas as pd

# %%
df = pd.read_csv("chat.csv")
df
# Out:
#                       date         user                  messages   only_date  \
# 0      2024-07-11 15:24:00  Ayyub Aunty                       💀💀💀  2024-07-11
# 1      2024-07-11 15:24:00       Atharv  Tera hi idea tya chutiye  2024-07-11
# 2      2024-07-11 15:25:00  Ayyub Aunty     Grp dekh banaya kisne  2024-07-11
# 3      2024-07-11 15:25:00        Saish           <Media omitted>  2024-07-11
# 4      2024-07-11 15:50:00       Atharv  Bc lect nai karre kya ??  2024-07-11
# ...                    ...          ...                       ...         ...
# 15460  2025-08-08 11:33:00     Himanshu                   Nahi re  2025-08-08
# 15461  2025-08-08 11:34:00  Ayyub Aunty                     Nopes  2025-08-08
# 15462  2025-08-08 11:34:00       Atharv   Bs session krke return?  2025-08-08
# 15463  2025-08-08 15:40:00        Saish           <Media omitted>  2025-08-08
# 15464  2025-08-08 15:40:00     Himanshu    Aaj hi aayi ye reel xd  2025-08-08
#
# ...

# %%
df['user'].unique()
# Out:
# array(['Ayyub Aunty', 'Atharv', 'Saish', 'Harsh', 'Himanshu',
#        'Sanket Dudhwala', 'Sudhirwa', 'Vipin N', 'Meta AI'], dtype=object)
